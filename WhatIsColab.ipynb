# %% [markdown]
# # What is CoLab?
# I wanted to answer that question.  So, this is a collection of commands to probe the Colaboratory environment to figure out what exists and what can be done with it ... other than just Python.

# %% [markdown]
# We'll use Jupyter's '!' magic to run shell commands.

# %%
# !uname -a
# Out:
# Linux fbc0f0198ce2 5.4.188+ #1 SMP Sun Apr 24 10:03:06 PDT 2022 x86_64 x86_64 x86_64 GNU/Linux

# %% [markdown]
# Ah-ha!  It seems like we have an x86 Linux system.
# What ditribution are we running?

# %%
# !cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.5 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.5 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %% [markdown]
# Hmmm.  So we are running a slightly older version of Ubuntu.

# %% [markdown]
# ## Storage
# How much local storage space is available?

# %%
# !df -hTPl
# Out:
# Filesystem     Type        Size  Used Avail Use% Mounted on
# overlay        overlay     108G   39G   70G  36% /
# tmpfs          tmpfs        64M     0   64M   0% /dev
# shm            tmpfs       5.8G     0  5.8G   0% /dev/shm
# /dev/root      ext2        2.0G  1.2G  812M  59% /sbin/docker-init
# tmpfs          tmpfs       6.4G   28K  6.4G   1% /var/colab
# /dev/sda1      ext4         81G   43G   39G  53% /etc/hosts
# tmpfs          tmpfs       6.4G     0  6.4G   0% /proc/acpi
# tmpfs          tmpfs       6.4G     0  6.4G   0% /proc/scsi
# tmpfs          tmpfs       6.4G     0  6.4G   0% /sys/firmware
# drive          fuse.drive  100G   41G   60G  41% /content/drive

# %% [markdown]
# Looks like about 100G with 70GB free.  Makes me wonder what's taking up those 39GB; a question for another time.

# %% [markdown]
# What user am I running as?

# %%
# !whoami ; id
# Out:
# root
# uid=0(root) gid=0(root) groups=0(root)

# %% [markdown]
# Ooo, root!  That brings up all kinds of possibilities.

# %% [markdown]
# What is the current folder?

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# What's in the current folder?

# %%
# !ls -la
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Jul 19 18:28 .
# drwxr-xr-x 1 root root 4096 Jul 19 18:27 ..
# drwxr-xr-x 4 root root 4096 Jul 13 13:42 .config
# drwx------ 5 root root 4096 Jul 19 18:28 drive
# drwxr-xr-x 1 root root 4096 Jul 13 13:43 sample_data

# %% [markdown]
# What is in the root (/) folder?

# %%
# !ls -la /
# Out:
# total 108
# drwxr-xr-x   1 root root 4096 Jul 19 18:27 .
# drwxr-xr-x   1 root root 4096 Jul 19 18:27 ..
# drwxr-xr-x   1 root root 4096 Jul 13 13:33 bin
# drwxr-xr-x   2 root root 4096 Apr 24  2018 boot
# drwxr-xr-x   1 root root 4096 Jul 19 18:28 content
# drwxr-xr-x   1 root root 4096 Jul 16 00:06 datalab
# drwxr-xr-x   5 root root  360 Jul 19 18:27 dev
# -rwxr-xr-x   1 root root    0 Jul 19 18:27 .dockerenv
# drwxr-xr-x   1 root root 4096 Jul 19 18:27 etc
# drwxr-xr-x   2 root root 4096 Apr 24  2018 home
# drwxr-xr-x   1 root root 4096 Jul 13 13:34 lib
# drwxr-xr-x   2 root root 4096 Jul 13 13:21 lib32
# drwxr-xr-x   1 root root 4096 Jul 13 13:21 lib64
# drwxr-xr-x   2 root root 4096 Nov 19  2020 media
# drwxr-xr-x   2 root root 4096 Nov 19  2020 mnt
# drwxr-xr-x   1 root root 4096 Jul 13 13:36 opt
# dr-xr-xr-x 189 root root    0 Jul 19 18:27 proc
# drwxr-xr-x  14 root root 4096 Jul 13 13:35 python-apt
# drwx------   1 root root 4096 Jul 18 18:04 root
# ...

# %% [markdown]
# What is in /home?

# %%
# !ls -la /home
# Out:
# total 8
# drwxr-xr-x 2 root root 4096 Apr 24  2018 .
# drwxr-xr-x 1 root root 4096 Jul 19 18:27 ..

# %% [markdown]
# ok, that suggests there are no regular users on this system.

# %% [markdown]
# ## Process environment

# %% [markdown]
# What environment variables are set?

# %%
# !env | sort
# Out:
# CLICOLOR=1
# CLOUDSDK_CONFIG=/content/.config
# CLOUDSDK_PYTHON=python3
# COLAB_GPU=0
# CUDA_VERSION=11.1.1
# CUDNN_VERSION=8.0.5.39
# DATALAB_SETTINGS_OVERRIDES={"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=172.28.0.2"],"debugAdapterMultiplexerPath":"/usr/local/bin/dap_multiplexer","enableLsp":true}
# DEBIAN_FRONTEND=noninteractive
# ENABLE_DIRECTORYPREFETCHER=1
# ENV=/root/.bashrc
# GCE_METADATA_TIMEOUT=3
# GCS_READ_CACHE_BLOCK_SIZE_MB=16
# GIT_PAGER=cat
# GLIBCPP_FORCE_NEW=1
# GLIBCXX_FORCE_NEW=1
# HOME=/root
# HOSTNAME=fbc0f0198ce2
# JPY_PARENT_PID=42
# LANG=en_US.UTF-8
# LAST_FORCED_REBUILD=20220712
# LD_LIBRARY_PATH=/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# LD_PRELOAD=/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4
# LIBRARY_PATH=/usr/local/cuda/lib64/stubs
# MPLBACKEND=module://ipykernel.pylab.backend_inline
# NCCL_VERSION=2.7.8
# NO_GCE_CHECK=False
# NVIDIA_DRIVER_CAPABILITIES=compute,utility
# ...

# %% [markdown]
# What processes are running?

# %%
# !ps faux | cat  # the pipe to cat is needed so that output does not get truncated.
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root          17  0.6  0.0  35888  4820 ?        Ss   18:27   0:00 tail -n +0 -F /root/.config/Google/DriveFS/Logs/dpb.txt /root/.config/Google/DriveFS/Logs/drive_fs.txt
# root           1  0.6  0.0    992     4 ?        Ss   18:27   0:00 /sbin/docker-init -- /datalab/run.sh
# root           7  0.7  0.3 337768 48416 ?        Sl   18:27   0:00 /tools/node/bin/node /datalab/web/app.js
# root          28  6.6  0.0      0     0 ?        Z    18:27   0:05  \_ [python3] <defunct>
# root          29  0.5  0.3 155880 40688 ?        S    18:27   0:00  \_ python3 /usr/local/bin/colab-fileshim.py
# root          42  1.8  0.4 199296 59848 ?        Rl   18:27   0:01  \_ /usr/bin/python3 /usr/local/bin/jupyter-notebook --ip=172.28.0.2 --port=9000 --FileContentsManager.root_dir=/ --MappingKernelManager.root_dir=/content
# ...

# %% [markdown]
# Looks like this is a Docker container.

# %%
# %%capture
# the file is copyrighted by Google.  Comment out the %%capture to view the output
# !cat -n /datalab/run.sh

# %% [markdown]
# What processes are listening on TCP ports?

# %%
# !netstat -plnt
# Out:
# /bin/bash: netstat: command not found

# %% [markdown]
# Bummer that netstat is not installed ... for now.

# %% [markdown]
# ## Hardware
# CPUs

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.208
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.41
# clflush size	: 64
# ...

# %% [markdown]
# ok.  Two CPUs with decent speed.
#
# How much RAM?

# %%
# !free -tm
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:          12986         580       10429           1        1977       12164
# Swap:             0           0           0
# Total:        12986         580       10429

# %% [markdown]
# Nice!  Looks like 12GB+ of RAM.  That's more than my Chromebook.  ;)
#
# How many network interfaces?

# %%
# !ifconfig -a
# Out:
# /bin/bash: ifconfig: command not found

# %% [markdown]
# Bummer, no ifconfig ... yet.

# %% [markdown]
# But do we have networking?  That is, what's my external IP address?

# %%
# !curl 'https://api.ipify.org?format=json'
# Out:
# {"ip":"34.125.27.36"}

# %%
# !jq -V
# Out:
# /bin/bash: jq: command not found

# %% [markdown]
# Bummer, no jq ... yet.

# %% [markdown]
# ## Programs
# Let's install netstat and a few other tools

# %%
# %%capture
# %%bash
apt-get update
apt-get install -y net-tools jq uuid tree elinks iproute2
# There's a lot of output.  Comment out the %%capture to view it.

# %% [markdown]
# Let's try those network interfaces again.

# %%
# !ifconfig -a
# Out:
# eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 172.28.0.2  netmask 255.255.0.0  broadcast 172.28.255.255
#         ether 02:42:ac:1c:00:02  txqueuelen 0  (Ethernet)
#         RX packets 6982  bytes 15993747 (15.9 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 6588  bytes 840363 (840.3 KB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# lo: flags=73<UP,LOOPBACK,RUNNING>  mtu 65536
#         inet 127.0.0.1  netmask 255.0.0.0
#         loop  txqueuelen 1000  (Local Loopback)
#         RX packets 1865  bytes 1078434 (1.0 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 1865  bytes 1078434 (1.0 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# %% [markdown]
# ok.  A loopback and a single ethernet with a private IP address.  That's not surprising that we are running behind some kind of NAT.

# %% [markdown]
# Let's try that external IP address again and filter it throught jq.

# %%
# !curl -s 'https://api.ipify.org?format=json' | jq .
# Out:
# {
#   "ip": "34.125.27.36"
# }

# %% [markdown]
# What processes are listening on TCP ports?

# %%
# !netstat -plnt
# Out:
# Active Internet connections (only servers)
# Proto Recv-Q Send-Q Local Address           Foreign Address         State       PID/Program name
# tcp        0      0 127.0.0.1:45821         0.0.0.0:*               LISTEN      79/python3
# tcp        0      0 0.0.0.0:3453            0.0.0.0:*               LISTEN      29/python3
# tcp        0      0 127.0.0.1:24767         0.0.0.0:*               LISTEN      79/python3
# tcp        0      0 127.0.0.1:56993         0.0.0.0:*               LISTEN      59/python3
# tcp        0      0 127.0.0.1:45219         0.0.0.0:*               LISTEN      79/python3
# tcp        0      0 127.0.0.1:45923         0.0.0.0:*               LISTEN      59/python3
# tcp        0      0 127.0.0.1:42823         0.0.0.0:*               LISTEN      59/python3
# tcp        0      0 127.0.0.1:51943         0.0.0.0:*               LISTEN      59/python3
# tcp        0      0 172.28.0.2:9000         0.0.0.0:*               LISTEN      42/python3
# ...

# %% [markdown]
# Hmm. No ssh server.
#
# Does an ssh client exist and, if so, what version?

# %%
# !ssh -V
# Out:
# OpenSSH_7.6p1 Ubuntu-4ubuntu0.7, OpenSSL 1.0.2n  7 Dec 2017

# %% [markdown]
# Are there ssh keys?

# %%
# !ls -la ~/.ssh/
# Out:
# ls: cannot access '/root/.ssh/': No such file or directory

# %% [markdown]
# Nope.  So, let's create an ssh key pair.

# %%
# !ssh-keygen -f ~/.ssh/id_ecdsa -N '' -t ecdsa
# Out:
# Generating public/private ecdsa key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_ecdsa.
# Your public key has been saved in /root/.ssh/id_ecdsa.pub.
# The key fingerprint is:
# SHA256:QduQoT+qBCIlFhrtRDQEZoy4SHnvPSsjZhQ7vYa8d58 root@fbc0f0198ce2
# The key's randomart image is:
# +---[ECDSA 256]---+
# |*X*     +o       |
# |*=+o   o.+       |
# |==o . . o .      |
# |+o.. . . .       |
# |o . = . S        |
# |.. = o + .       |
# |  o + o o        |
# |   B B o  .      |
# |  o.* + .E       |
# +----[SHA256]-----+

# %%
# !ls -la ~/.ssh/
# Out:
# total 20
# drwx------ 2 root root 4096 Jul 19 18:29 .
# drwx------ 1 root root 4096 Jul 19 18:29 ..
# -rw------- 1 root root  227 Jul 19 18:29 id_ecdsa
# -rw-r--r-- 1 root root  179 Jul 19 18:29 id_ecdsa.pub

# %% [markdown]
# Is git installed?

# %%
# !git --version
# Out:
# git version 2.17.1

# %% [markdown]
# Nice!  In theory, we can now use git with ssh to clone, fetch, pull, and push to GitHub.

# %% [markdown]
# Are there any checksum programs?

# %%
# !ls -1 /usr/bin/*sum*
# Out:
# /usr/bin/b2sum
# /usr/bin/cksum
# /usr/bin/gdalchksum.py
# /usr/bin/md5sum
# /usr/bin/md5sum.textutils
# /usr/bin/sha1sum
# /usr/bin/sha224sum
# /usr/bin/sha256sum
# /usr/bin/sha384sum
# /usr/bin/sha512sum
# /usr/bin/shasum
# /usr/bin/sum

# %%
# !echo -n '' | sha256sum
# Out:
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855  -

# %%
# !echo -n '' | md5sum
# Out:
# d41d8cd98f00b204e9800998ecf8427e  -

# %% [markdown]
# How about UUID?

# %%
# !uuid
# Out:
# b9783ecc-0790-11ed-b4d4-0242ac1c0002

# %% [markdown]
# Yay!!

# %% [markdown]
# ## Shell environment
# We've already been using the shell via the magic commands, but let's probe it a bit.

# %%
# !bash --version
# Out:
# GNU bash, version 4.4.20(1)-release (x86_64-pc-linux-gnu)
# Copyright (C) 2016 Free Software Foundation, Inc.
# License GPLv3+: GNU GPL version 3 or later <http://gnu.org/licenses/gpl.html>
#
# This is free software; you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.

# %%
# %%script bash
# echo $BASH_VERSION
# Out:
# 4.4.20(1)-release

# %%
# !which bash
# Out:
# /bin/bash

# %% [markdown]
# Any other shells?

# %%
# !ls -la /bin/*sh*
# Out:
# -rwxr-xr-x 1 root root 1113504 Jun  6  2019 /bin/bash
# -rwxr-xr-x 1 root root  121432 Jan 25  2018 /bin/dash
# lrwxrwxrwx 1 root root       4 Jun  6  2019 /bin/rbash -> bash
# lrwxrwxrwx 1 root root       4 Nov 19  2020 /bin/sh -> dash
# lrwxrwxrwx 1 root root       4 Nov 19  2020 /bin/sh.distrib -> dash

# %% [markdown]
# ## Python
# One of the points of Jupyter is to run an interactiver version of Python.  So, let's probe what modules are available to Python.

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ------------------------------
# absl-py                       1.1.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.4
# Babel                         2.10.3
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.1
# blis                          0.7.8
# bokeh                         2.3.3
# branca                        0.5.0
# ...

# %% [markdown]
# Wow!  That's a lot.
#
# Let's count how many PyPi packages are installed.

# %%
# !pip list | tail -n +3 | wc -l
# Out:
# 399

# %% [markdown]
# Let's do the same using some Jupyter magic.

# %%
pip_list = !pip list
pip_list[0:10]
# Out:
# ['Package                       Version',
#  '----------------------------- ------------------------------',
#  'absl-py                       1.1.0',
#  'alabaster                     0.7.12',
#  'albumentations                0.1.12',
#  'altair                        4.2.0',
#  'appdirs                       1.4.4',
#  'argon2-cffi                   21.3.0',
#  'argon2-cffi-bindings          21.2.0',
#  'arviz                         0.12.1']

# %%
len(pip_list[2:])
# Out:
# 399

# %% [markdown]
# That's nice to see that we get the same number.

# %% [markdown]
# What environment variables are set for Python?

# %%
# !env | grep -i python
# Out:
# CLOUDSDK_PYTHON=python3
# PYTHONWARNINGS=ignore:::pip._internal.cli.base_command
# PYTHONPATH=/env/python

# %%
# !ls -la ${PYTHONPATH}
# Out:
# ls: cannot access '/env/python': No such file or directory

# %% [markdown]
# What's the default search path for Python modules?

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# What version of Python is running?

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=13, releaselevel='final', serial=0)

# %% [markdown]
# Look!  Sorted dictionaries.

# %%
{ "b": "2", "a": "1"}
# Out:
# {'a': '1', 'b': '2'}

# %% [markdown]
# ## Convert Notebook to other formats

# %%
# !jupyter nbconvert --to markdown --output-dir=. ./drive/MyDrive/Colab\ Notebooks/WhatIsColab.ipynb
# Out:
# [NbConvertApp] Converting notebook ./drive/MyDrive/Colab Notebooks/WhatIsColab.ipynb to markdown
# [NbConvertApp] Writing 17129 bytes to ./WhatIsColab.md

# %%
# !jupyter nbconvert --to python --output-dir=. ./drive/MyDrive/Colab\ Notebooks/WhatIsColab.ipynb
# Out:
# [NbConvertApp] Converting notebook ./drive/MyDrive/Colab Notebooks/WhatIsColab.ipynb to python
# [NbConvertApp] Writing 6410 bytes to ./WhatIsColab.py

# %%
# !jupyter nbconvert --to html --output-dir=. ./drive/MyDrive/Colab\ Notebooks/WhatIsColab.ipynb
# Out:
# [NbConvertApp] Converting notebook ./drive/MyDrive/Colab Notebooks/WhatIsColab.ipynb to html
# [NbConvertApp] Writing 326095 bytes to ./WhatIsColab.html

# %%
# !jupyter nbconvert --to slides --output-dir=. ./drive/MyDrive/Colab\ Notebooks/WhatIsColab.ipynb
# Out:
# [NbConvertApp] Converting notebook ./drive/MyDrive/Colab Notebooks/WhatIsColab.ipynb to slides
# [NbConvertApp] Writing 331354 bytes to ./WhatIsColab.slides.html

# %%
# !jupyter nbconvert --to pdf --output-dir=. ./drive/MyDrive/Colab\ Notebooks/WhatIsColab.ipynb
# Out:
# [NbConvertApp] Converting notebook ./drive/MyDrive/Colab Notebooks/WhatIsColab.ipynb to pdf
# [NbConvertApp] Writing 54537 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/nbconvert/nbconvertapp.py", line 340, in start
#     self.convert_notebooks()
#   File "/usr/local/lib/python3.7/dist-packages/nbconvert/nbconvertapp.py", line 510, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
# ...

# %% [markdown]
# Bummer that xelatex is not installed.  Let's install it.

# %%
# %%capture
# %%bash
apt-get update
apt-get install -y texlive-xetex

# %%
# !jupyter nbconvert --to pdf --output-dir=. ./drive/MyDrive/Colab\ Notebooks/WhatIsColab.ipynb
# Out:
# [NbConvertApp] Converting notebook ./drive/MyDrive/Colab Notebooks/WhatIsColab.ipynb to pdf
# [NbConvertApp] Writing 79904 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 80032 bytes to ./WhatIsColab.pdf
